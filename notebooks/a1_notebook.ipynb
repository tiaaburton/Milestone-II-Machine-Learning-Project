# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install pyspark --quiet
! pip install plotly --quiet
! pip install chart_studio --quiet
! pip install spark_sklearn --quiet
! pip install flake8_nb --quiet
# Out:
#      |████████████████████████████████| 281.4 MB 30 kB/s
#      |████████████████████████████████| 198 kB 56.6 MB/s
#   Building wheel for pyspark (setup.py) ... done
#      |████████████████████████████████| 64 kB 2.3 MB/s
#   Building wheel for retrying (setup.py) ... done
#      |████████████████████████████████| 4.9 MB 5.4 MB/s
#   Building wheel for spark-sklearn (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.4 requires scikit-learn>=1.0.0, but you have scikit-learn 0.19.2 which is incompatible.
# imbalanced-learn 0.8.1 requires scikit-learn>=0.24, but you have scikit-learn 0.19.2 which is incompatible.
#      |████████████████████████████████| 793 kB 6.9 MB/s
#      |████████████████████████████████| 64 kB 1.4 MB/s
#      |████████████████████████████████| 42 kB 593 kB/s
#      |████████████████████████████████| 69 kB 4.2 MB/s
#      |████████████████████████████████| 381 kB 39.4 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# markdown 3.3.7 requires importlib-metadata>=4.4; python_version < "3.10", but you have importlib-metadata 4.2.0 which is incompatible.
# jupyter-console 5.2.0 requires prompt-toolkit<2.0.0,>=1.0.0, but you have prompt-toolkit 3.0.29 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.34.0 which is incompatible.

# %%
import pandas as pd
import numpy as np
import os
import sys
import random
import time
import ast
import pickle
import flake8_nb

from google.cloud import bigquery
from google.colab import auth, files
from typing import Union
from spark_sklearn import Converter

import pyspark
from pyspark.sql.window import Window
from pyspark.sql.functions import *
from pyspark.sql import SparkSession
from pyspark.ml import *
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.classification import *
from pyspark.ml.feature import *
from pyspark.ml.evaluation import BinaryClassificationEvaluator

from sklearn.dummy import DummyClassifier
from sklearn.metrics import precision_score, recall_score, roc_auc_score, f1_score
from sklearn.feature_selection import mutual_info_classif

import chart_studio.plotly as py
import plotly.graph_objs as go
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/least_angle.py:35: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/least_angle.py:597: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/least_angle.py:836: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/least_angle.py:1074: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=1, eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/least_angle.py:1306: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=1, eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/least_angle.py:1442: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/randomized_l1.py:152: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   precompute=False, eps=np.finfo(np.float).eps,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/randomized_l1.py:318: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, random_state=None,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/randomized_l1.py:575: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=4 * np.finfo(np.float).eps, n_jobs=1,

# %%
def pyspark_column_prep(dataset):
  """Returns column names with underscores for PySpark ready format.
     dataset: pd.DataFrame"""
  for col in dataset.columns:
    if '.' in col:
      repl = col.replace('.','_').replace(' ','_')
      dataset.rename(columns={col: repl},inplace=True)

  return dataset
  
def get_mutual_info_features(train_df, target_df, thres:float):
  MI = mutual_info_classif(train_df, target_df)
  mi_results = sorted(list(zip(MI, train_df.columns)), key=lambda x: x[0], reverse=True)

  mi_features = []
  for idx,item in enumerate(mi_results):
    val, col = item
    if val > thres:
      mi_features.append(col)
  mi_features.append('label')

  return mi_features,mi_results

# %% [markdown]
# #### Mutual Information (Information Gain)
#
# For binary classification, the sklearn library provides a method to get the mutual information score with the feature and the target variable. This paper explains how mutual information could improve ROC Curve results. Source: [National Library of Medicine](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7597205/)

# %%
RANDOM_SEED = 655

a1_b2_dataset = pd.read_csv(
    '/content/drive/Shareddrives/SIADS - 694-695 Team Drive/datasets/model_files/A1_B2_data.csv'
)

spark_ready_X = pyspark_column_prep(a1_b2_dataset)

train = spark_ready_X[spark_ready_X.columns[~spark_ready_X.columns.isin([
                                                                         'Monetary',
                                                                         'buyers',
                                                                         'Frequency',
                                                                         'repurchasers',
                                                                         'Recency',
                                                                         'totals_transactions',
                                                                         'date',
                                                                         'fullVisitorId'
                                                                         ])]].fillna(0.0)
target = a1_b2_dataset[['totals_transactions']]
target = target.totals_transactions.fillna(0.0).apply(lambda trans: trans if trans == 0.0 else 1.0)
target = pd.Categorical(target)
target = pd.Series(target)

filter1,mi1 = get_mutual_info_features(train, target, 0.0)
filter2,_ = get_mutual_info_features(train, target, .001)
filter3,_ = get_mutual_info_features(train, target, .05)

mi1 = pd.DataFrame(mi1, columns=['mutual_info_score', 'column_name'])

# %% [markdown]
# ## PySpark Cluster
#
# 1. Create a spark session using the local compute.
# 2. If you have not exited the last Spark session, it will remain open. To forcible start a new session, with new environment variables, run the newSession() method.

# %%
spark = SparkSession.builder \
    .master("local[*]") \
    .appName("Binary Buyer Prediction") \
    .getOrCreate()

# %%
spark.newSession()
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://82b5e111fa74:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Binary Buyer Prediction</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Methodology:
# Transformations:
# - PCA=2 was the conscensus among the group. Added to the pipeline for binary classification probability prediction for likelihood to buy. (Did not incorporate at this time.)
# - Remove columns from Mutual Information step earlier
# - Under sampling - using the same number of customers / visits labels
# - Train(,val), test: Overall, the dataset is split into 90% train and 10% test. The train dataset will be split into a 75% training and 25% validation data because this is the behavior of the Cross Validator.
#
# *Ethical consideration*: continued to exclude fullvisitorid because it was not useful for understanding if a customer was likely to return or not. It is better to understand what patterns, or behaviors, arise from those who are interacting with the site in order to better predict if the random visitor is a buyer and subsequently someone to target with marketing.

# %%
def downsampling(data):
  df = data.withColumn('rand_col', rand())
  balanced_data = df.withColumn(
      "row_num",row_number().over(Window.partitionBy("label")\
                                  .orderBy("rand_col"))).filter(col("row_num")<=label_balance.head(2)[1][1])\
                                  .drop("rand_col", "row_num")
  return balanced_data

def take_random_sample(data):
  return data.sample(True, .1, RANDOM_SEED)

# %%
train_spark = (spark.createDataFrame(spark_ready_X)
                    .withColumn('label', col('totals_transactions')))

# %%
unbalanced_df = train_spark.withColumn('label', when(col('label')==0.0, 0).otherwise(1.0))
label_balance = unbalanced_df.groupBy('label').count().withColumnRenamed('count','unbalanced_count')

downsample_df = downsampling(unbalanced_df)
random_df = take_random_sample(unbalanced_df)

dlabel_df = downsample_df.select('label').groupBy('label').count().withColumnRenamed('count','downsampling_count')
rlabel_df = random_df.select('label').groupBy('label').count().withColumnRenamed('count','randsamp_count')

(label_balance.join(dlabel_df,how='inner',on='label')
              .join(rlabel_df,how='inner',on='label')).show()
# Out:
# +-----+----------------+------------------+--------------+
# |label|unbalanced_count|downsampling_count|randsamp_count|
# +-----+----------------+------------------+--------------+
# |  0.0|           49516|              5865|          4828|
# |  1.0|            5865|              5865|           600|
# +-----+----------------+------------------+--------------+

# %% [markdown]
# Models:
# - Logistic Regression (baseline model since pyspark doesn't have a dummy classifier - could still compare, but it's ok for now.)
# - Decision Tree (more robust model)
# - Random Forest Classifier (most robust model for classification)
#
#
# Metrics: Precision, Recall, AUC, and F1-Score (Harmonious Combo of Precision and Recall)
#
# MLFlow tracking was tested in this environment, but it was not a successful strategy for the charting and continued components in the pipeline. Removed and would be considered if more time or resources avalaible.

# %%
X_train_unbalanced, X_test_unbalanced = unbalanced_df.randomSplit([0.9, 0.1], seed=RANDOM_SEED)
X_train_dsample, X_test_dsample = downsample_df.randomSplit([0.9, 0.1], seed=RANDOM_SEED)
X_train_random, X_test_random  = random_df.randomSplit([0.9, 0.1], seed=RANDOM_SEED)

# %%
def cv_model(model, train, test, param_grid=None):
  if not param_grid: param_grid = ParamGridBuilder().build()
  cols = [col for col in train.columns if col not in set(['totals_transactions','label','fullVisitorId'])]
  vec = VectorAssembler(inputCols=cols, outputCol='features', handleInvalid='skip')
  pipeline = Pipeline(stages=[vec, model])

  evaluator = BinaryClassificationEvaluator()

  crossval = CrossValidator(estimator=pipeline,
                            estimatorParamMaps=param_grid,
                            evaluator=evaluator,
                            numFolds=4) 
  # increased the number of folds from 4 to 10 after initial testing as 10, time increased drastically
  
  crossval = crossval.fit(train)
  best_model = crossval.bestModel.stages[-1]
  validation_res = crossval.transform(train)
  prediction_res = crossval.transform(test)
  
  train_eval = crossval.getEvaluator().evaluate(validation_res)
  test_eval = crossval.getEvaluator().evaluate(prediction_res)
  return best_model, train_eval, test_eval, validation_res, prediction_res
  
def save_model(model, file_loc, model_name):
  filename = file_loc + '/' + f'a1_{model_name}_model.sav'
  try:
    model.save(filename)
  except:
    model.write().overwrite().save(filename)
  return

def convert_model(spark_model):
  conv = Converter(spark)
  sklearn_model = conv.toSKLearn(spark_model)
  return sklearn_model

# %%
def get_clf_metrics(data:pyspark.sql.dataframe.DataFrame, true:str, pred:str):
  pred_df = data.select(true,pred).toPandas()
  recall = recall_score(pred_df['label'], pred_df['prediction'])
  f1Score = f1_score(pred_df['label'], pred_df['prediction'])
  precision = precision_score(pred_df['label'], pred_df['prediction'])
  return recall, f1Score, precision

def train_spark_models(spark_datasets, spark_models, param_grids, filters, models):

  trained_models = []
  df = pd.DataFrame()
  datasets = []

  for model in models:
    for names, data in spark_datasets.items():
      train_name, test_name = names
      X_train, X_test = data

      for filter in filters:

        if model in spark_models.keys():

          start_time = time.time()
          trained_model, train_eval, test_eval, validation, predictions = \
          cv_model(spark_models[model],X_train[filter], X_test[filter], param_grid=param_grids[model])

          try:
            best_params = trained_model._java_obj.extractParamMap()
          except:
            best_params = trained_model._java_obj.parent().extractParamMap()
          end_time = time.time()

          datasets.append((validation, predictions))
          trained_models.append(trained_model)

          train_recall, train_f1Score, train_precision = get_clf_metrics(validation,'label','prediction')
          test_recall, test_f1Score, test_precision = get_clf_metrics(predictions,'label','prediction')

          df2 = pd.DataFrame([[model, train_name, filter, len(filter), train_eval, train_recall, 
                               train_precision, train_f1Score, best_params, start_time, end_time]],
                      columns=['Model', 'Dataset', 'Column_Filter', 'Col_Num',
                               'AUC', 'Recall', 'Precision', 'F1-Score', 'Best_Params',
                               'Start_Time', 'End_Time'])
          df3 = pd.DataFrame([[model, test_name, filter, len(filter), test_eval, test_recall, 
                               test_precision, test_f1Score, best_params, start_time, end_time]],
                      columns=['Model', 'Dataset','Column_Filter', 'Col_Num',
                               'AUC', 'Recall', 'Precision', 'F1-Score', 'Best_Params',
                               'Start_Time', 'End_Time'])
          if len(df) == 0:
            df = pd.concat([df2, df3], ignore_index=True)
          else:
            df = pd.concat([df, df2, df3], ignore_index=True)

  return trained_models, df, datasets

def post_processing(df):
  for idx,param_grid in enumerate(df.Best_Params.apply(lambda x: str(x)[3:-2])):
    for param_str in (param_grid.split(',\n\t')):
      param = param_str.split(':')
      param[0] = param[0].split('-')[-1]

      if param[0] not in df.columns:
        df[param[0]] = np.nan
      if param[0] in df.columns and len(param) > 1: 
        df[param[0]].iloc[idx] = param[1]
  return df

def save_models(df, models, force:bool=False):

  for idx,model in enumerate(models):
    try:
      dataset = df.iloc[idx]['Test_Dataset'].split("_")[-1]
      col_num = df.iloc[idx]['Col_Num']
      f_name = df.iloc[idx]['Model'] + f'run{idx}_{dataset}_{col_num}_col'

      save_model(model, '../content/drive/Shareddrives/SIADS - 694-695 Team Drive/models/spark_models',
                      f_name)
    except Exception as e:
      print(f'Failed because {e};', model)
  return

# %% [markdown]
# #### Technical finding
# CrossValidator.bestModel.stages[-1]._java_obj.extractParamMap() creates a Java Gateway member like `<py4j.java_gateway.JavaMember at 0x7f11e2b55210>`. It provides the params for the best trained PySpark model; alternatively, this could return all params (or results with a small tweak) for all the iteratively trained models. This gives the same functionality as if it were an independently trained estimator.

# %%
spark_datasets = {
    ('X_train_unbalanced', 'X_test_unbalanced'): (X_train_unbalanced, X_test_unbalanced),
    ('X_train_dsample', 'X_test_dsample'): (X_train_dsample, X_test_dsample),
    ('X_train_random', 'X_test_random'): (X_train_random, X_test_random)
  }

spark_models ={
    'spark_lr': LogisticRegression(maxIter=100000, featuresCol='features',labelCol='label'),
    'spark_dt': classification.DecisionTreeClassifier(featuresCol="features", labelCol="label"),
    'spark_rf': RandomForestClassifier(featuresCol="features", labelCol="label")
}

param_grids ={
    'spark_lr': ParamGridBuilder()\
    .addGrid(spark_models['spark_lr'].regParam, [1.0, 2.0]) \
    .addGrid(spark_models['spark_lr'].elasticNetParam, [0.0, 0.5, 1]) \
    .build(),
    'spark_dt': ParamGridBuilder()\
    .addGrid(spark_models['spark_dt'].maxDepth, [1, 2, 3]) \
    .addGrid(spark_models['spark_dt'].minInfoGain, [0.0, .005, .01, .1]) \
    .build(),
    'spark_rf': ParamGridBuilder()\
    .addGrid(spark_models['spark_rf'].maxDepth, [1, 2, 3])\
    .addGrid(spark_models['spark_rf'].numTrees, [10, 20, 40]) \
    .build()
}

models, df, datasets = train_spark_models(spark_datasets, spark_models, param_grids,
                                          [filter1, filter2, filter3], ['spark_lr', 'spark_dt', 'spark_rf'])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning:
#
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 due to no predicted samples.

# %%
save_models(df, models, force=False)
# Out:
#     index     Model       Train_Dataset       Test_Dataset  \
# 25     25  spark_dt     X_train_dsample     X_test_dsample
# 27     27  spark_dt     X_train_dsample     X_test_dsample
# 29     29  spark_dt     X_train_dsample     X_test_dsample
# 47     47  spark_rf     X_train_dsample     X_test_dsample
# 43     43  spark_rf     X_train_dsample     X_test_dsample
# 45     45  spark_rf     X_train_dsample     X_test_dsample
# 24     24  spark_dt     X_train_dsample     X_test_dsample
# 26     26  spark_dt     X_train_dsample     X_test_dsample
# 28     28  spark_dt     X_train_dsample     X_test_dsample
# 46     46  spark_rf     X_train_dsample     X_test_dsample
# 44     44  spark_rf     X_train_dsample     X_test_dsample
# 42     42  spark_rf     X_train_dsample     X_test_dsample
# 11     11  spark_lr     X_train_dsample     X_test_dsample
# 10     10  spark_lr     X_train_dsample     X_test_dsample
# 8       8  spark_lr     X_train_dsample     X_test_dsample
# 6       6  spark_lr     X_train_dsample     X_test_dsample
# 9       9  spark_lr     X_train_dsample     X_test_dsample
# 7       7  spark_lr     X_train_dsample     X_test_dsample
# 50     50  spark_rf      X_train_random      X_test_random
# 49     49  spark_rf      X_train_random      X_test_random
# 31     31  spark_dt      X_train_random      X_test_random
# 33     33  spark_dt      X_train_random      X_test_random
# 30     30  spark_dt      X_train_random      X_test_random
# 32     32  spark_dt      X_train_random      X_test_random
# 48     48  spark_rf      X_train_random      X_test_random
# 53     53  spark_rf      X_train_random      X_test_random
# 52     52  spark_rf      X_train_random      X_test_random
# 51     51  spark_rf      X_train_random      X_test_random
# 39     39  spark_rf  X_train_unbalanced  X_test_unbalanced
# 37     37  spark_rf  X_train_unbalanced  X_test_unbalanced
# 38     38  spark_rf  X_train_unbalanced  X_test_unbalanced
# 36     36  spark_rf  X_train_unbalanced  X_test_unbalanced
# 35     35  spark_dt      X_train_random      X_test_random
# 18     18  spark_dt  X_train_unbalanced  X_test_unbalanced
# 20     20  spark_dt  X_train_unbalanced  X_test_unbalanced
# 19     19  spark_dt  X_train_unbalanced  X_test_unbalanced
# 21     21  spark_dt  X_train_unbalanced  X_test_unbalanced
# 40     40  spark_rf  X_train_unbalanced  X_test_unbalanced
# 34     34  spark_dt      X_train_random      X_test_random
# 41     41  spark_rf  X_train_unbalanced  X_test_unbalanced
# 23     23  spark_dt  X_train_unbalanced  X_test_unbalanced
# 22     22  spark_dt  X_train_unbalanced  X_test_unbalanced
# 16     16  spark_lr      X_train_random      X_test_random
# 4       4  spark_lr  X_train_unbalanced  X_test_unbalanced
# 5       5  spark_lr  X_train_unbalanced  X_test_unbalanced
# 2       2  spark_lr  X_train_unbalanced  X_test_unbalanced
# 0       0  spark_lr  X_train_unbalanced  X_test_unbalanced
# 14     14  spark_lr      X_train_random      X_test_random
# 12     12  spark_lr      X_train_random      X_test_random
# 3       3  spark_lr  X_train_unbalanced  X_test_unbalanced
# 1       1  spark_lr  X_train_unbalanced  X_test_unbalanced
# 15     15  spark_lr      X_train_random      X_test_random
# 13     13  spark_lr      X_train_random      X_test_random
# 17     17  spark_lr      X_train_random      X_test_random
#
#                                         Column_Filter  Col_Num       AUC  \
# 25  ['totals_pageviews', 'totals_hits', 'totals_ti...       35  0.967630
# 27  ['totals_pageviews', 'totals_hits', 'totals_ti...       28  0.967630
# 29  ['totals_pageviews', 'totals_hits', 'totals_ti...        7  0.969265
# 47  ['totals_pageviews', 'totals_hits', 'totals_ti...        7  0.982658
# 43  ['totals_pageviews', 'totals_hits', 'totals_ti...       35  0.983552
# 45  ['totals_pageviews', 'totals_hits', 'totals_ti...       28  0.985829
# 24  ['totals_pageviews', 'totals_hits', 'totals_ti...       35  0.956112
# 26  ['totals_pageviews', 'totals_hits', 'totals_ti...       28  0.956112
# 28  ['totals_pageviews', 'totals_hits', 'totals_ti...        7  0.957459
# 46  ['totals_pageviews', 'totals_hits', 'totals_ti...        7  0.979051
# 44  ['totals_pageviews', 'totals_hits', 'totals_ti...       28  0.981493
# 42  ['totals_pageviews', 'totals_hits', 'totals_ti...       35  0.979510
# 11  ['totals_pageviews', 'totals_hits', 'totals_ti...        7  0.981998
# 10  ['totals_pageviews', 'totals_hits', 'totals_ti...        7  0.977421
# 8   ['totals_pageviews', 'totals_hits', 'totals_ti...       28  0.963579
# 6   ['totals_pageviews', 'totals_hits', 'totals_ti...       35  0.963246
# 9   ['totals_pageviews', 'totals_hits', 'totals_ti...       28  0.967445
# 7   ['totals_pageviews', 'totals_hits', 'totals_ti...       35  0.967099
# 50  ['totals_pageviews', 'totals_hits', 'totals_ti...       28  0.983210
# 49  ['totals_pageviews', 'totals_hits', 'totals_ti...       35  0.982850
# 31  ['totals_pageviews', 'totals_hits', 'totals_ti...       35  0.875335
# 33  ['totals_pageviews', 'totals_hits', 'totals_ti...       28  0.875335
# 30  ['totals_pageviews', 'totals_hits', 'totals_ti...       35  0.888134
# 32  ['totals_pageviews', 'totals_hits', 'totals_ti...       28  0.888134
# 48  ['totals_pageviews', 'totals_hits', 'totals_ti...       35  0.982741
# 53  ['totals_pageviews', 'totals_hits', 'totals_ti...        7  0.979225
# 52  ['totals_pageviews', 'totals_hits', 'totals_ti...        7  0.980228
# 51  ['totals_pageviews', 'totals_hits', 'totals_ti...       28  0.984422
# 39  ['totals_pageviews', 'totals_hits', 'totals_ti...       28  0.980766
# 37  ['totals_pageviews', 'totals_hits', 'totals_ti...       35  0.980219
# 38  ['totals_pageviews', 'totals_hits', 'totals_ti...       28  0.981636
# 36  ['totals_pageviews', 'totals_hits', 'totals_ti...       35  0.981296
# 35  ['totals_pageviews', 'totals_hits', 'totals_ti...        7  0.906447
# 18  ['totals_pageviews', 'totals_hits', 'totals_ti...       35  0.960888
# 20  ['totals_pageviews', 'totals_hits', 'totals_ti...       28  0.960888
# 19  ['totals_pageviews', 'totals_hits', 'totals_ti...       35  0.962317
# 21  ['totals_pageviews', 'totals_hits', 'totals_ti...       28  0.962317
# 40  ['totals_pageviews', 'totals_hits', 'totals_ti...        7  0.960577
# 34  ['totals_pageviews', 'totals_hits', 'totals_ti...        7  0.911161
# 41  ['totals_pageviews', 'totals_hits', 'totals_ti...        7  0.956674
# 23  ['totals_pageviews', 'totals_hits', 'totals_ti...        7  0.915905
# 22  ['totals_pageviews', 'totals_hits', 'totals_ti...        7  0.919144
# 16  ['totals_pageviews', 'totals_hits', 'totals_ti...        7  0.977128
# 4   ['totals_pageviews', 'totals_hits', 'totals_ti...        7  0.975911
# 5   ['totals_pageviews', 'totals_hits', 'totals_ti...        7  0.976102
# 2   ['totals_pageviews', 'totals_hits', 'totals_ti...       28  0.974951
# 0   ['totals_pageviews', 'totals_hits', 'totals_ti...       35  0.974676
# 14  ['totals_pageviews', 'totals_hits', 'totals_ti...       28  0.975573
# 12  ['totals_pageviews', 'totals_hits', 'totals_ti...       35  0.975236
# 3   ['totals_pageviews', 'totals_hits', 'totals_ti...       28  0.974332
# 1   ['totals_pageviews', 'totals_hits', 'totals_ti...       35  0.974104
# 15  ['totals_pageviews', 'totals_hits', 'totals_ti...       28  0.984481
# 13  ['totals_pageviews', 'totals_hits', 'totals_ti...       35  0.984306
# 17  ['totals_pageviews', 'totals_hits', 'totals_ti...        7  0.980695
#
#       Recall  Precision  F1-Score  ... maxDepth  maxMemoryInMB  minInfoGain  \
# 25  0.982206   0.945205  0.963351  ...      3.0          256.0        0.005
# 27  0.982206   0.945205  0.963351  ...      3.0          256.0        0.005
# 29  0.980427   0.945111  0.962445  ...      3.0          256.0        0.000
# 47  0.983986   0.940476  0.961739  ...      3.0          256.0        0.000
# 43  0.985765   0.935811  0.960139  ...      3.0          256.0        0.000
# 45  0.983986   0.935702  0.959237  ...      3.0          256.0        0.000
# 24  0.978117   0.929378  0.953125  ...      3.0          256.0        0.005
# 26  0.978117   0.929378  0.953125  ...      3.0          256.0        0.005
# 28  0.975099   0.929175  0.951583  ...      3.0          256.0        0.000
# 46  0.976608   0.918559  0.946695  ...      3.0          256.0        0.000
# 44  0.978495   0.913043  0.944637  ...      3.0          256.0        0.000
# 42  0.979626   0.910893  0.944010  ...      3.0          256.0        0.000
# 11  0.992883   0.891374  0.939394  ...      NaN            NaN          NaN
# 10  0.991700   0.881160  0.933168  ...      NaN            NaN          NaN
# 8   0.947934   0.861626  0.902722  ...      NaN            NaN          NaN
# 6   0.947746   0.861306  0.902461  ...      NaN            NaN          NaN
# 9   0.953737   0.852146  0.900084  ...      NaN            NaN          NaN
# 7   0.950178   0.851675  0.898234  ...      NaN            NaN          NaN
# 50  0.804924   0.817308  0.811069  ...      3.0          256.0        0.000
# 49  0.763889   0.859375  0.808824  ...      3.0          256.0        0.000
# 31  0.819444   0.797297  0.808219  ...      3.0          256.0        0.000
# 33  0.819444   0.797297  0.808219  ...      3.0          256.0        0.000
# 30  0.833333   0.781528  0.806599  ...      3.0          256.0        0.000
# 32  0.833333   0.781528  0.806599  ...      3.0          256.0        0.000
# 48  0.791667   0.821218  0.806172  ...      3.0          256.0        0.000
# 53  0.805556   0.805556  0.805556  ...      3.0          256.0        0.000
# 52  0.821970   0.787659  0.804449  ...      3.0          256.0        0.000
# 51  0.763889   0.846154  0.802920  ...      3.0          256.0        0.000
# 39  0.784411   0.807167  0.795627  ...      3.0          256.0        0.000
# 37  0.789386   0.797320  0.793333  ...      3.0          256.0        0.000
# 38  0.793726   0.790720  0.792220  ...      3.0          256.0        0.000
# 36  0.800760   0.780723  0.790615  ...      3.0          256.0        0.000
# 35  0.861111   0.729412  0.789809  ...      1.0          256.0        0.000
# 18  0.860266   0.729133  0.789290  ...      3.0          256.0        0.000
# 20  0.860266   0.729133  0.789290  ...      3.0          256.0        0.000
# 19  0.852405   0.731152  0.787136  ...      3.0          256.0        0.000
# 21  0.852405   0.731152  0.787136  ...      3.0          256.0        0.000
# 40  0.802091   0.766812  0.784055  ...      3.0          256.0        0.000
# 34  0.865530   0.708527  0.779199  ...      1.0          256.0        0.000
# 41  0.779436   0.774300  0.776860  ...      3.0          256.0        0.000
# 23  0.887231   0.662949  0.758865  ...      1.0          256.0        0.000
# 22  0.893726   0.655283  0.756152  ...      1.0          256.0        0.000
# 16  0.045455   0.857143  0.086331  ...      NaN            NaN          NaN
# 4   0.036122   0.883721  0.069406  ...      NaN            NaN          NaN
# 5   0.023217   0.875000  0.045234  ...      NaN            NaN          NaN
# 2   0.007605   0.888889  0.015080  ...      NaN            NaN          NaN
# 0   0.007605   0.888889  0.015080  ...      NaN            NaN          NaN
# 14  0.003788   0.666667  0.007533  ...      NaN            NaN          NaN
# 12  0.003788   0.666667  0.007533  ...      NaN            NaN          NaN
# 3   0.003317   0.666667  0.006601  ...      NaN            NaN          NaN
# 1   0.003317   0.666667  0.006601  ...      NaN            NaN          NaN
# 15  0.000000   0.000000  0.000000  ...      NaN            NaN          NaN
# 13  0.000000   0.000000  0.000000  ...      NaN            NaN          NaN
# 17  0.000000   0.000000  0.000000  ...      NaN            NaN          NaN
#
#     minInstancesPerNode  minWeightFractionPerNode          seed bootstrap  \
# 25                  1.0                       0.0  7.882335e+18       NaN
# 27                  1.0                       0.0  7.882335e+18       NaN
# 29                  1.0                       0.0  7.882335e+18       NaN
# 47                  1.0                       0.0  3.577578e+18      true
# 43                  1.0                       0.0  3.577578e+18      true
# 45                  1.0                       0.0  3.577578e+18      true
# 24                  1.0                       0.0  7.882335e+18       NaN
# 26                  1.0                       0.0  7.882335e+18       NaN
# 28                  1.0                       0.0  7.882335e+18       NaN
# 46                  1.0                       0.0  3.577578e+18      true
# 44                  1.0                       0.0  3.577578e+18      true
# 42                  1.0                       0.0  3.577578e+18      true
# 11                  NaN                       NaN           NaN       NaN
# 10                  NaN                       NaN           NaN       NaN
# 8                   NaN                       NaN           NaN       NaN
# 6                   NaN                       NaN           NaN       NaN
# 9                   NaN                       NaN           NaN       NaN
# 7                   NaN                       NaN           NaN       NaN
# 50                  1.0                       0.0  3.577578e+18      true
# 49                  1.0                       0.0  3.577578e+18      true
# 31                  1.0                       0.0  7.882335e+18       NaN
# 33                  1.0                       0.0  7.882335e+18       NaN
# 30                  1.0                       0.0  7.882335e+18       NaN
# 32                  1.0                       0.0  7.882335e+18       NaN
# 48                  1.0                       0.0  3.577578e+18      true
# 53                  1.0                       0.0  3.577578e+18      true
# 52                  1.0                       0.0  3.577578e+18      true
# 51                  1.0                       0.0  3.577578e+18      true
# 39                  1.0                       0.0  3.577578e+18      true
# 37                  1.0                       0.0  3.577578e+18      true
# 38                  1.0                       0.0  3.577578e+18      true
# 36                  1.0                       0.0  3.577578e+18      true
# 35                  1.0                       0.0  7.882335e+18       NaN
# 18                  1.0                       0.0  7.882335e+18       NaN
# 20                  1.0                       0.0  7.882335e+18       NaN
# 19                  1.0                       0.0  7.882335e+18       NaN
# 21                  1.0                       0.0  7.882335e+18       NaN
# 40                  1.0                       0.0  3.577578e+18      true
# 34                  1.0                       0.0  7.882335e+18       NaN
# 41                  1.0                       0.0  3.577578e+18      true
# 23                  1.0                       0.0  7.882335e+18       NaN
# 22                  1.0                       0.0  7.882335e+18       NaN
# 16                  NaN                       NaN           NaN       NaN
# 4                   NaN                       NaN           NaN       NaN
# 5                   NaN                       NaN           NaN       NaN
# 2                   NaN                       NaN           NaN       NaN
# 0                   NaN                       NaN           NaN       NaN
# 14                  NaN                       NaN           NaN       NaN
# 12                  NaN                       NaN           NaN       NaN
# 3                   NaN                       NaN           NaN       NaN
# 1                   NaN                       NaN           NaN       NaN
# 15                  NaN                       NaN           NaN       NaN
# 13                  NaN                       NaN           NaN       NaN
# 17                  NaN                       NaN           NaN       NaN
#
#    featureSubsetStrategy numTrees  subsamplingRate
# 25                   NaN      NaN              NaN
# 27                   NaN      NaN              NaN
# 29                   NaN      NaN              NaN
# 47                  auto     20.0              1.0
# 43                  auto     20.0              1.0
# 45                  auto     40.0              1.0
# 24                   NaN      NaN              NaN
# 26                   NaN      NaN              NaN
# 28                   NaN      NaN              NaN
# 46                  auto     20.0              1.0
# 44                  auto     40.0              1.0
# 42                  auto     20.0              1.0
# 11                   NaN      NaN              NaN
# 10                   NaN      NaN              NaN
# 8                    NaN      NaN              NaN
# 6                    NaN      NaN              NaN
# 9                    NaN      NaN              NaN
# 7                    NaN      NaN              NaN
# 50                  auto     40.0              1.0
# 49                  auto     40.0              1.0
# 31                   NaN      NaN              NaN
# 33                   NaN      NaN              NaN
# 30                   NaN      NaN              NaN
# 32                   NaN      NaN              NaN
# 48                  auto     40.0              1.0
# 53                  auto     40.0              1.0
# 52                  auto     40.0              1.0
# 51                  auto     40.0              1.0
# 39                  auto     20.0              1.0
# 37                  auto     40.0              1.0
# 38                  auto     20.0              1.0
# 36                  auto     40.0              1.0
# 35                   NaN      NaN              NaN
# 18                   NaN      NaN              NaN
# 20                   NaN      NaN              NaN
# 19                   NaN      NaN              NaN
# 21                   NaN      NaN              NaN
# 40                  auto     10.0              1.0
# 34                   NaN      NaN              NaN
# 41                  auto     10.0              1.0
# 23                   NaN      NaN              NaN
# 22                   NaN      NaN              NaN
# 16                   NaN      NaN              NaN
# 4                    NaN      NaN              NaN
# 5                    NaN      NaN              NaN
# 2                    NaN      NaN              NaN
# 0                    NaN      NaN              NaN
# 14                   NaN      NaN              NaN
# 12                   NaN      NaN              NaN
# 3                    NaN      NaN              NaN
# 1                    NaN      NaN              NaN
# 15                   NaN      NaN              NaN
# 13                   NaN      NaN              NaN
# 17                   NaN      NaN              NaN
#
# [54 rows x 43 columns]

# %%
df = post_processing(df)
df = df.reset_index()
df.sort_values(['F1-Score','AUC'],ascending=False).to_csv('/content/drive/Shareddrives/SIADS - 694-695 Team Drive/results/a1_final_results.csv')

# %% [markdown]
# ### To Load Models:
# Use the calls below to select an individual model to run predicitions on it now.

# %%
classification.RandomForestClassificationModel.load("/content/drive/Shareddrives/SIADS - 694-695 Team Drive/models/a1_spark_rf_dsample_model.sav")
classification.DecisionTreeClassificationModel.load("/content/drive/Shareddrives/SIADS - 694-695 Team Drive/models/a1_spark_dt_dsample_model.sav")
classification.LogisticRegressionModel.load("/content/drive/Shareddrives/SIADS - 694-695 Team Drive/models/a1_spark_lr_dsample_model.sav")

# %% [markdown]
# ### Plotting results
# - Multi plot Scatter Chart with F1-Score vs AUC Score per dataset type
# - 3d Scatter Plot with F1-Score, regParam, elasticNetParam
# - Bar Chart: F1-Score
# - Bar Chart: Recall
# - Bar Chart: Precision

# %%
df = pd.read_csv('/content/drive/Shareddrives/SIADS - 694-695 Team Drive/results/a1_final_results.csv',index_col=0)
df = post_processing(df)
df['Dataset_Category'] = df['Dataset'].apply(lambda x: x.split('_')[-1])
df['Dataset_Type'] = df['Dataset'].apply(lambda x: x.split('_')[1])
df = df.reset_index()
print(df.columns)
df.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Index(['index', 'Model', 'Dataset', 'Column_Filter', 'Col_Num', 'AUC',
#        'Recall', 'Precision', 'F1-Score', 'Best_Params', 'Start_Time',
#        'End_Time', 'cacheNodeIds', 'checkpointInterval', 'featuresCol',
#        'impurity', 'labelCol', 'leafCol', 'maxBins', 'maxDepth',
#        'maxMemoryInMB', 'minInfoGain', 'minInstancesPerNode',
#        'minWeightFractionPerNode', 'predictionCol', 'probabilityCol',
#        'rawPredictionCol', 'seed', 'bootstrap', 'featureSubsetStrategy',
#        'numTrees', 'subsamplingRate', 'aggregationDepth', 'elasticNetParam',
#        'family', 'fitIntercept', 'maxBlockSizeInMB', 'maxIter', 'regParam',
#        'standardization', 'threshold', 'tol', 'Dataset_Category',
#        'Dataset_Type'],
#       dtype='object')
#    index     Model          Dataset  \
# 0     24  spark_dt  X_train_dsample
# 1     26  spark_dt  X_train_dsample
#
#                                        Column_Filter  Col_Num       AUC  \
# 0  ['totals_pageviews', 'totals_hits', 'totals_ti...       31  0.958938
# 1  ['totals_pageviews', 'totals_hits', 'totals_ti...       26  0.958938
#
#      Recall  Precision  F1-Score  \
# 0  0.971009   0.933406  0.951836
# 1  0.971009   0.933406  0.951836
#
#                                          Best_Params  ...  family  \
# 0  {\n\tDecisionTreeClassifier_41fca20da5b7-cache...  ...     NaN
# 1  {\n\tDecisionTreeClassifier_41fca20da5b7-cache...  ...     NaN
#
#    fitIntercept maxBlockSizeInMB maxIter regParam standardization threshold  \
# 0           NaN              NaN     NaN      NaN             NaN       NaN
# 1           NaN              NaN     NaN      NaN             NaN       NaN
#
#    tol Dataset_Category Dataset_Type
# 0  NaN          dsample        train
# 1  NaN          dsample        train
#
# [2 rows x 44 columns]

# %%
fig1 = px.scatter(df, x="AUC", y="F1-Score", facet_col="Col_Num", facet_row="Model", 
                 title="Likelihood to Buy Binary Classification", color='Dataset'
                 )
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bfb71795-5a06-4ac3-964b-d69ff50c6284" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfb71795-5a06-4ac3-964b-d69ff50c6284")) {                    Plotly.newPlot(                        "bfb71795-5a06-4ac3-964b-d69ff50c6284",                        [{"hovertemplate":"Dataset=X_train_dsample<br>Model=spark_dt<br>Col_Num=31<br>AUC=%{x}<br>F1-Score=%{y}<extra></extra>","legendgroup":"X_train_dsample","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"X_train_dsample","orientation":"v","showlegend":true,"x":[0.9589377624760372],"xaxis":"x7","y":[0.9518361321276988],"yaxis":"y7","type":"scatter"},{"hovertemplate":"Dataset=X_train_dsample<br>Model=spark_dt<br>Col_Num=26<br>AUC=%{x}<br>F1-Score=%{y}<extra></extra>","legendgroup":"X_train_dsample","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"X_train_dsample","orientation":"v","showlegend":false,"x":[0.9589377624760372],"xaxis":"x8","y":[0.9518361321276988],"yaxis":"y8","type":"scatter"},{"hovertemplate":"Dataset=X_train_dsample<br>Model=spark_dt<br>Col_Num=7<br>AUC=%{x}<br>F1-Score=%{y}<extra></extra>","legendgroup":"X_train_dsample","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"X_train_dsample","orientation":"v","showlegend":false,"x":[0.9589377624760372],"xaxis":"x9","y":[0.9518361321276988],"yaxis":"y9","type":"scatter"},{"hovertemplate":"Dataset=X_train_dsample<br>Model=spark_rf<br>Col_Num=31<br>AUC=%{x}<br>F1-Score=%{y}<extra></extra>","legendgroup":"X_train_dsample","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"X_train_dsample","orientation":"v","showlegend":false,"x":[0.981013328870194],"xaxis":"x4","y":[0.948024948024948],"yaxis":"y4","type":"scatter"},{"hovertemplate":"Dataset=X_train_dsample<br>Model=spark_rf<br>Col_Num=26<br>AUC=%{x}<br>F1-Score=%{y}<extra></extra>","legendgroup":"X_train_dsample","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"X_train_dsample","orientation":"v","showlegend":false,"x":[0.9818586109562466],"xaxis":"x5","y":[0.9486087192966556],"yaxis":"y5","type":"scatter"},{"hovertemplate":"Dataset=X_train_dsample<br>Model=spark_rf<br>Col_Num=7<br>AUC=%{x}<br>F1-Score=%{y}<extra></extra>","legendgroup":"X_train_dsample","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"X_train_dsample","orientation":"v","showlegend":false,"x":[0.9789676259085268],"xaxis":"x6","y":[0.9497510185604346],"yaxis":"y6","type":"scatter"},{"hovertemplate":"Dataset=X_train_dsample<br>Model=spark_lr<br>Col_Num=31<br>AUC=%{x}<br>F1-Score=%{y}<extra></extra>","legendgroup":"X_train_dsample","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"X_train_dsample","orientation":"v","showlegend":false,"x":[0.9626646758663712],"xaxis":"x","y":[0.902521910212842],"yaxis":"y","type":"scatter"},{"hovertemplate":"Dataset=X_train_dsample<br>Model=spark_lr<br>Col_Num=26<br>AUC=%{x}<br>F1-Score=%{y}<extra></extra>","legendgroup":"X_train_dsample","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"X_train_dsample","orientation":"v","showlegend":false,"x":[0.962655732688006],"xaxis":"x2","y":[0.9024237545836687],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Dataset=X_train_dsample<br>Model=spark_lr<br>Col_Num=7<br>AUC=%{x}<br>F1-Score=%{y}<extra></extra>","legendgroup":"X_train_dsample","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"X_train_dsample","orientation":"v","showlegend":false,"x":[0.9768667465709602],"xaxis":"x3","y":[0.9315407748098354],"yaxis":"y3","type":"scatter"},{"hovertemplate":"Dataset=X_test_dsample<br>Model=spark_dt<br>Col_Num=31<br>AUC=%{x}<br>F1-Score=%{y}<extra></extra>","legen ...

# %%
df[df['Model']=='spark_rf'].groupby('Model')['AUC', 'F1-Score'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                AUC  F1-Score
# Model
# spark_rf  0.979983  0.843942

# %%
df[(df['Model']=='spark_lr') & ~('dsample' in df['Dataset'])].groupby('Model')['AUC', 'F1-Score'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#               AUC  F1-Score
# Model
# spark_lr  0.97469  0.318247

# %%
fig2 = px.scatter_3d(df[df['Model']=='spark_lr'], x="regParam", y="elasticNetParam", z="F1-Score",
              title="Logistic Regression Params vs F1-Score in Likelihood to Buy Binary Classification", 
              color='Dataset', symbol='Col_Num'
          )
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4fadfa5a-3e62-4438-b5b0-32830237a38f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4fadfa5a-3e62-4438-b5b0-32830237a38f")) {                    Plotly.newPlot(                        "4fadfa5a-3e62-4438-b5b0-32830237a38f",                        [{"hovertemplate":"Dataset=X_test_dsample<br>Col_Num=7<br>regParam=%{x}<br>elasticNetParam=%{y}<br>F1-Score=%{z}<extra></extra>","legendgroup":"X_test_dsample, 7","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"X_test_dsample, 7","scene":"scene","showlegend":true,"x":[null],"y":[null],"z":[0.9336734693877552],"type":"scatter3d"},{"hovertemplate":"Dataset=X_test_dsample<br>Col_Num=31<br>regParam=%{x}<br>elasticNetParam=%{y}<br>F1-Score=%{z}<extra></extra>","legendgroup":"X_test_dsample, 31","marker":{"color":"#636efa","symbol":"diamond"},"mode":"markers","name":"X_test_dsample, 31","scene":"scene","showlegend":true,"x":[" 1.0"],"y":[" 0.0"],"z":[0.8998272884283246],"type":"scatter3d"},{"hovertemplate":"Dataset=X_test_dsample<br>Col_Num=26<br>regParam=%{x}<br>elasticNetParam=%{y}<br>F1-Score=%{z}<extra></extra>","legendgroup":"X_test_dsample, 26","marker":{"color":"#636efa","symbol":"square"},"mode":"markers","name":"X_test_dsample, 26","scene":"scene","showlegend":true,"x":[" 1.0"],"y":[" 0.0"],"z":[0.8990509059534082],"type":"scatter3d"},{"hovertemplate":"Dataset=X_train_dsample<br>Col_Num=7<br>regParam=%{x}<br>elasticNetParam=%{y}<br>F1-Score=%{z}<extra></extra>","legendgroup":"X_train_dsample, 7","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"X_train_dsample, 7","scene":"scene","showlegend":true,"x":[" 1.0"],"y":[" 0.0"],"z":[0.9315407748098354],"type":"scatter3d"},{"hovertemplate":"Dataset=X_train_dsample<br>Col_Num=31<br>regParam=%{x}<br>elasticNetParam=%{y}<br>F1-Score=%{z}<extra></extra>","legendgroup":"X_train_dsample, 31","marker":{"color":"#EF553B","symbol":"diamond"},"mode":"markers","name":"X_train_dsample, 31","scene":"scene","showlegend":true,"x":[" 1.0"],"y":[" 0.0"],"z":[0.902521910212842],"type":"scatter3d"},{"hovertemplate":"Dataset=X_train_dsample<br>Col_Num=26<br>regParam=%{x}<br>elasticNetParam=%{y}<br>F1-Score=%{z}<extra></extra>","legendgroup":"X_train_dsample, 26","marker":{"color":"#EF553B","symbol":"square"},"mode":"markers","name":"X_train_dsample, 26","scene":"scene","showlegend":true,"x":[" 1.0"],"y":[" 0.0"],"z":[0.9024237545836687],"type":"scatter3d"},{"hovertemplate":"Dataset=X_train_random<br>Col_Num=7<br>regParam=%{x}<br>elasticNetParam=%{y}<br>F1-Score=%{z}<extra></extra>","legendgroup":"X_train_random, 7","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"X_train_random, 7","scene":"scene","showlegend":true,"x":[" 1.0"],"y":[" 0.0"],"z":[0.0863309352517985],"type":"scatter3d"},{"hovertemplate":"Dataset=X_train_random<br>Col_Num=31<br>regParam=%{x}<br>elasticNetParam=%{y}<br>F1-Score=%{z}<extra></extra>","legendgroup":"X_train_random, 31","marker":{"color":"#00cc96","symbol":"diamond"},"mode":"markers","name":"X_train_random, 31","scene":"scene","showlegend":true,"x":[" 2.0"],"y":[" 0.0"],"z":[0.007532956685499],"type":"scatter3d"},{"hovertemplate":"Dataset=X_train_random<br>Col_Num=26<br>regParam=%{x}<br>elasticNetParam=%{y}<br>F1-Score=%{z}<extra></extra>","legendgroup":"X_train_random, 26","marker":{"color":"#00cc96","symbol":"square"},"mode":"markers","name":"X_train_random, 26","scene":"scene","showlegend":true,"x":[" 2.0"],"y":[" 0.0"],"z":[0.007532956685499],"type":"scatter3d"},{"hovertemplate":"Dataset=X_train_unbalanced<br>Col_Num=7<br>regParam=%{x}<br>elasticNetParam=%{y}<br>F1-Score=%{z}<extra></extra>","legendgroup":"X_train_unbalanced, 7","marker":{"color":"#ab63fa","symbol":" ...

# %%
fig3 = px.bar(df[df['Model']=='spark_lr'], x="index", y="F1-Score", color="Dataset_Type", text_auto='.2',
              title="Logistic Regression F1-Score in Likelihood to Buy Binary Classification", 
              facet_col="Dataset_Category", 
          )
fig3.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f21e5a85-1b94-4f68-96a7-218b031409a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f21e5a85-1b94-4f68-96a7-218b031409a5")) {                    Plotly.newPlot(                        "f21e5a85-1b94-4f68-96a7-218b031409a5",                        [{"alignmentgroup":"True","hovertemplate":"Dataset_Type=test<br>Dataset_Category=dsample<br>index=%{x}<br>F1-Score=%{y}<extra></extra>","legendgroup":"test","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"test","offsetgroup":"test","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2}","x":[11,7,9],"xaxis":"x","y":[0.9336734693877552,0.8998272884283246,0.8990509059534082],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dataset_Type=test<br>Dataset_Category=random<br>index=%{x}<br>F1-Score=%{y}<extra></extra>","legendgroup":"test","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"test","offsetgroup":"test","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2}","x":[13,15,17],"xaxis":"x2","y":[0.0,0.0,0.0],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dataset_Type=test<br>Dataset_Category=unbalanced<br>index=%{x}<br>F1-Score=%{y}<extra></extra>","legendgroup":"test","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"test","offsetgroup":"test","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2}","x":[5,3,1],"xaxis":"x3","y":[0.0452342487883683,0.0066006600660066,0.0066006600660066],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dataset_Type=train<br>Dataset_Category=dsample<br>index=%{x}<br>F1-Score=%{y}<extra></extra>","legendgroup":"train","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"train","offsetgroup":"train","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2}","x":[10,6,8],"xaxis":"x","y":[0.9315407748098354,0.902521910212842,0.9024237545836687],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dataset_Type=train<br>Dataset_Category=random<br>index=%{x}<br>F1-Score=%{y}<extra></extra>","legendgroup":"train","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"train","offsetgroup":"train","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2}","x":[16,12,14],"xaxis":"x2","y":[0.0863309352517985,0.007532956685499,0.007532956685499],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dataset_Type=train<br>Dataset_Category=unbalanced<br>index=%{x}<br>F1-Score=%{y}<extra></extra>","legendgroup":"train","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"train","offsetgroup":"train","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2}","x":[4,0,2],"xaxis":"x3","y":[0.0694063926940639,0.0150801131008482,0.0150801131008482],"yaxis":"y3","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111111 ...

# %%
fig4 = px.bar(df[df['Model']=='spark_lr'], x="index", y="Recall", color="Dataset_Type", text_auto='.2',
              title="Logistic Regression Recall Scores in Likelihood to Buy Binary Classification",  
              facet_col="Dataset_Category", 
          )
fig4.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="54bf14de-9400-4cdd-915e-4bde4e9ee7b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54bf14de-9400-4cdd-915e-4bde4e9ee7b0")) {                    Plotly.newPlot(                        "54bf14de-9400-4cdd-915e-4bde4e9ee7b0",                        [{"alignmentgroup":"True","hovertemplate":"Dataset_Type=test<br>Dataset_Category=dsample<br>index=%{x}<br>Recall=%{y}<extra></extra>","legendgroup":"test","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"test","offsetgroup":"test","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2}","x":[11,7,9],"xaxis":"x","y":[0.9963702359346642,0.9455535390199638,0.9455535390199638],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dataset_Type=test<br>Dataset_Category=random<br>index=%{x}<br>Recall=%{y}<extra></extra>","legendgroup":"test","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"test","offsetgroup":"test","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2}","x":[13,15,17],"xaxis":"x2","y":[0.0,0.0,0.0],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dataset_Type=test<br>Dataset_Category=unbalanced<br>index=%{x}<br>Recall=%{y}<extra></extra>","legendgroup":"test","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"test","offsetgroup":"test","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2}","x":[5,3,1],"xaxis":"x3","y":[0.0232172470978441,0.0033167495854063,0.0033167495854063],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dataset_Type=train<br>Dataset_Category=dsample<br>index=%{x}<br>Recall=%{y}<extra></extra>","legendgroup":"train","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"train","offsetgroup":"train","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2}","x":[10,6,8],"xaxis":"x","y":[0.9913403614457832,0.9499246987951808,0.9497364457831324],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dataset_Type=train<br>Dataset_Category=random<br>index=%{x}<br>Recall=%{y}<extra></extra>","legendgroup":"train","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"train","offsetgroup":"train","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2}","x":[16,12,14],"xaxis":"x2","y":[0.0454545454545454,0.0037878787878787,0.0037878787878787],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dataset_Type=train<br>Dataset_Category=unbalanced<br>index=%{x}<br>Recall=%{y}<extra></extra>","legendgroup":"train","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"train","offsetgroup":"train","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2}","x":[4,0,2],"xaxis":"x3","y":[0.0361216730038022,0.0076045627376425,0.0076045627376425],"yaxis":"y3","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111111111111111 ...

# %%
fig5 = px.bar(df[df['Model']=='spark_lr'], x="index", y="Precision", color="Dataset_Type", text_auto='.2',
              title="Logistic Regression Precision Scores in Likelihood to Buy Binary Classification",  
              facet_col="Dataset_Category", 
          )
fig5.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))
fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3ead9404-1db2-41fd-90ef-49283e312ed0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ead9404-1db2-41fd-90ef-49283e312ed0")) {                    Plotly.newPlot(                        "3ead9404-1db2-41fd-90ef-49283e312ed0",                        [{"alignmentgroup":"True","hovertemplate":"Dataset_Type=test<br>Dataset_Category=dsample<br>index=%{x}<br>Precision=%{y}<extra></extra>","legendgroup":"test","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"test","offsetgroup":"test","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2}","x":[11,7,9],"xaxis":"x","y":[0.8784,0.8583196046128501,0.8569078947368421],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dataset_Type=test<br>Dataset_Category=random<br>index=%{x}<br>Precision=%{y}<extra></extra>","legendgroup":"test","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"test","offsetgroup":"test","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2}","x":[13,15,17],"xaxis":"x2","y":[0.0,0.0,0.0],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dataset_Type=test<br>Dataset_Category=unbalanced<br>index=%{x}<br>Precision=%{y}<extra></extra>","legendgroup":"test","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"test","offsetgroup":"test","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2}","x":[5,3,1],"xaxis":"x3","y":[0.875,0.6666666666666666,0.6666666666666666],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dataset_Type=train<br>Dataset_Category=dsample<br>index=%{x}<br>Precision=%{y}<extra></extra>","legendgroup":"train","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"train","offsetgroup":"train","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2}","x":[10,6,8],"xaxis":"x","y":[0.8785452118785452,0.8596252129471891,0.8596012949395127],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dataset_Type=train<br>Dataset_Category=random<br>index=%{x}<br>Precision=%{y}<extra></extra>","legendgroup":"train","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"train","offsetgroup":"train","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2}","x":[16,12,14],"xaxis":"x2","y":[0.8571428571428571,0.6666666666666666,0.6666666666666666],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dataset_Type=train<br>Dataset_Category=unbalanced<br>index=%{x}<br>Precision=%{y}<extra></extra>","legendgroup":"train","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"train","offsetgroup":"train","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2}","x":[4,0,2],"xaxis":"x3","y":[0.8837209302325582,0.8888888888888888,0.8888888888888888],"yaxis":"y3","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#460 ...

# %%
# !pip install kaleido
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaleido in /usr/local/lib/python3.7/dist-packages (0.2.1)

# %%
import kaleido
titles = ["Likelihood to Buy Binary Classification",
          "Logistic Regression Params vs F1-Score in Likelihood to Buy Binary Classification",
          "Logistic Regression F1-Score in Likelihood to Buy Binary Classification",
          "Logistic Regression Recall Scores in Likelihood to Buy Binary Classification",
          "Logistic Regression Precision Scores in Likelihood to Buy Binary Classification"]

for idx,fig in enumerate([fig1, fig2, fig3, fig4, fig5]):
    file_name = '/content/drive/Shareddrives/SIADS - 694-695 Team Drive/visualizations/' + titles[idx]
    fig.write_html(file_name + '.html')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-2ccc3bc7604d> in <module>()
#       9     file_name = '/content/drive/Shareddrives/SIADS - 694-695 Team Drive/visualizations/' + titles[idx]
#      10     # fig.write_html(file_name + '.html')
# ---> 11     fig.write_image(file_name + '.jpeg')
#
# /usr/local/lib/python3.7/dist-packages/plotly/basedatatypes.py in write_image(self, *args, **kwargs)
#    3827         import plotly.io as pio
#    3828
# -> 3829         return pio.write_image(self, *args, **kwargs)
#    3830
#    3831     # Static helpers
#
# /usr/local/lib/python3.7/dist-packages/plotly/io/_kaleido.py in write_image(fig, file, format, scale, width, height, validate, engine)
#     273         height=height,
#     274         validate=validate,
# --> 275         engine=engine,
#     276     )
#     277
#
# /usr/local/lib/python3.7/dist-packages/plotly/io/_kaleido.py in to_image(fig, format, width, height, scale, validate, engine)
#     137 which can be installed using pip:
#     138     $ pip install -U kaleido
# --> 139 """
#     140         )
#     141
#
# ValueError:
# Image export using the "kaleido" engine requires the kaleido package,
# which can be installed using pip:
#     $ pip install -U kaleido

# %%
spark.sparkContext.stop()

# %% [markdown]
# ### Conclusion
# Though it was our benchmark model, the logistic regression performed worse than the other models. It was not robust, and was likely overfit for the unbalanced classes.
