# %%
# !git
# Out:
# usage: git [--version] [--help] [-C <path>] [-c <name>=<value>]
#            [--exec-path[=<path>]] [--html-path] [--man-path] [--info-path]
#            [-p | --paginate | --no-pager] [--no-replace-objects] [--bare]
#            [--git-dir=<path>] [--work-tree=<path>] [--namespace=<name>]
#            <command> [<args>]
#
# These are common Git commands used in various situations:
#
# start a working area (see also: git help tutorial)
#    clone      Clone a repository into a new directory
#    init       Create an empty Git repository or reinitialize an existing one
#
# work on the current change (see also: git help everyday)
#    add        Add file contents to the index
#    mv         Move or rename a file, a directory, or a symlink
#    reset      Reset current HEAD to the specified state
#    rm         Remove files from the working tree and from the index
#
# examine the history and state (see also: git help revisions)
# ...

# %% [markdown]
# #### TODO
# Delete the repo created with git init

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/.git/

# %%
ls /content/.git
# Out:
# branches/  config  description  HEAD  hooks/  info/  objects/  refs/

# %% [markdown]
# #### GitHub Commit from Google Colab
#
# Make sure github known who you are. I'm assuming that the Github repo is connected to the credentials I already have set up for pushing the Colab notebooks. This helps push other important files.

# %%
cd /content/drive/Shareddrives/SIADS - 694-695 Team Drive/Milestone-II-Machine-Learning-Project
# Out:
# /content/drive/Shareddrives/SIADS - 694-695 Team Drive/Milestone-II-Machine-Learning-Project

# %%
ls
# Out:
# datasets/  LICENSE  ml_pipeline/  old_notebooks/  README.md

# %%
# !git branch
# Out:
# * (HEAD detached from 69254bd)
#   latest_update
#   main

# %%
# !git pull origin main
# Out:
# From https://github.com/tiaaburton/Milestone-II-Machine-Learning-Project
#  * branch            main       -> FETCH_HEAD
#    07639c4..e71cd00  main       -> origin/main
# Already up to date.

# %%
# !cp ../visualizations/* ../Milestone-II-Machine-Learning-Project/visualizations

# %%
# !git add visualizations/

# %%
# !git config --global user.email "tiaaburton@me.com"
# !git config --global user.name "tiaaburton"

# %%
# !git commit -m "Adding visualization files."
# Out:
# [detached HEAD 09c6a1f] Adding visualization files.
#  23 files changed, 69 insertions(+)
#  create mode 100644 visualizations/B2_clustering_and_biplot.png
#  create mode 100644 visualizations/DBScan.png
#  create mode 100644 visualizations/a2_default_models.png
#  create mode 100644 visualizations/a2_feature_correlation_heatmap.png
#  create mode 100644 visualizations/a2_figure.png
#  create mode 100644 visualizations/a2_finetuned_feature_pruned_models.png
#  create mode 100644 visualizations/a2_finetuned_models.png
#  create mode 100644 visualizations/a2_finetuned_rebalanced_models.png
#  create mode 100644 visualizations/a2_kfold_analysis.png
#  create mode 100644 visualizations/adspy_temp.dot
#  create mode 100644 visualizations/dtree_pipe.png
#  create mode 100644 visualizations/elbow_kmeans.png
#  create mode 100644 visualizations/famd_by_buyers.png
#  create mode 100644 visualizations/famd_by_channel.png
#  create mode 100644 visualizations/kmeans_heat_map_pca_full.png
# ...

# %%
# !git status
# Out:
# HEAD detached from 69254bd
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	datasets/sample_dataset.csv
# 	visualizations/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %% [markdown]
# ### Using github in Google Colab:
# To push the to github, you would like to use the following command after adding your files.
#
# `!git push https://<YOUR-PERSONAL-ACCESS-TOKEN>@github.com/<User-Name>/<Repo-Name>.git`
#
# If you add files to this file directory, either in Google Drive directly or in colab, please push them to a new branch and compare and pull request.
#
# Mine: *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*

# %%
# !git pull origin main
# Out:
# From https://github.com/tiaaburton/Milestone-II-Machine-Learning-Project
#  * branch            main       -> FETCH_HEAD
# hint: Waiting for your editor to close the file... error: unable to start editor 'editor'
# Not committing merge; use 'git commit' to complete the merge.

# %%
# !git push https://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@github.com/tiaaburton/Milestone-II-Machine-Learning-Project.git HEAD:main
# Out:
# Counting objects: 12, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (12/12), done.
# Writing objects: 100% (12/12), 22.12 KiB | 1.58 MiB/s, done.
# Total 12 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 2 local objects.
# To https://github.com/tiaaburton/Milestone-II-Machine-Learning-Project.git
#    1e33c24..a9eb5cf  HEAD -> main

# %%
# !git remote update origin --prune
# Out:
# Fetching origin
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 21 (delta 10), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (21/21), done.
# From https://github.com/tiaaburton/Milestone-II-Machine-Learning-Project
#    97b24fd..1e33c24  main       -> origin/main

# %%
# !git log
# Out:
# commit 29d08b22b093a2000494bad3ed23198f5df28cc2 (HEAD)
# Merge: 67665cf e71cd00
# Author: tiaaburton <tiaaburton@me.com>
# Date:   Mon May 16 03:03:18 2022 +0000
#
#     Updating files and adding model files.
#
# commit 67665cfe2ccd7f2fef9eabffa77dfe715db64787
# Author: tiaaburton <tiaaburton@me.com>
# Date:   Mon May 16 02:59:06 2022 +0000
#
#     Adding model files.
#
# commit e71cd00eaf081f58f0d6bc90abf0653ee5c8f4ef (origin/main, origin/HEAD)
# Author: tiaaburton <tiaaburton@me.com>
# Date:   Sun May 15 05:09:05 2022 +0000
#
#     Deleting old files that were moved.
#
# commit 07639c4a2e575867c5f3b0cb887203c505da8d48
# Author: tiaaburton <tiaaburton@me.com>
# Date:   Sun May 15 05:06:44 2022 +0000
#
#     Completed data extraction, sampling, cleaning. Adding model files.
#
# commit 9dbd263ecaf563230a8079338a94415d0973fb9b
# Merge: b5260b7 73fc3f9
# Author: Tia <67672920+tiaaburton@users.noreply.github.com>
# Date:   Sat May 14 21:21:06 2022 -0700
#
# ...

# %%
# !git reset --hard 9dbd263ec
# Out:
# HEAD is now at 9dbd263 Merge pull request #1 from tiaaburton/latest_update

# %%
# !git pull origin main #--rebase
# Out:
# From https://github.com/tiaaburton/Milestone-II-Machine-Learning-Project
#  * branch            main       -> FETCH_HEAD
#    e71cd00..29d08b2  main       -> origin/main
# Already up to date.
